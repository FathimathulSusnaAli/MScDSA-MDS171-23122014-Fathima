# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
students = {
    "Name":["Naveen","Nikhil","Indu","Jeffin","Abin","Ram","Maya","Priya","Lamiya"],
    "Age" :[22,24,18,20,23,22,32,21,22]
}

# %%
print(students)
# Out:
# {'Name': ['Naveen', 'Nikhil', 'Indu', 'Jeffin', 'Abin', 'Ram', 'Maya', 'Priya', 'Lamiya'], 'Age': [22, 24, 18, 20, 23, 22, 32, 21, 22]}

# %%
df = pd.DataFrame(students)

# %%
print(df)
# Out:
#      Name  Age
# 0  Naveen   22
# 1  Nikhil   24
# 2    Indu   18
# 3  Jeffin   20
# 4    Abin   23
# 5     Ram   22
# 6    Maya   32
# 7   Priya   21
# 8  Lamiya   22

# %%
df.head() #top 5 by default
# Out:
#      Name  Age
# 0  Naveen   22
# 1  Nikhil   24
# 2    Indu   18
# 3  Jeffin   20
# 4    Abin   23

# %%
df.tail() #last 5 by default
# Out:
#      Name  Age
# 4    Abin   23
# 5     Ram   22
# 6    Maya   32
# 7   Priya   21
# 8  Lamiya   22

# %%
df.info() #gives the whole information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    9 non-null      object
#  1   Age     9 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 276.0+ bytes

# %%
#to load any data

df = pd.read_excel("Iraqi Student Performance Prediction.xlsx") # delimiter = "\t" :when the file consists of something

# %%
print(df.describe()) #stats values for numberical columns
# Out:
#        Student_ID         Age  Family Size  Internet Usage    TV Usage  \
# count  120.000000  120.000000   120.000000      120.000000  120.000000
# mean    60.500000    2.166667     0.500000        0.500000    0.141667
# std     34.785054    0.539737     0.648204        0.744729    0.435713
# min      1.000000    1.000000     0.000000        0.000000    0.000000
# 25%     30.750000    2.000000     0.000000        0.000000    0.000000
# 50%     60.500000    2.000000     0.000000        0.000000    0.000000
# 75%     90.250000    2.000000     1.000000        1.000000    0.000000
# max    120.000000    4.000000     2.000000        2.000000    2.000000
#
#        Sleep Hour  Study Hour  Arrival Time     Islamea      arabic  ...  \
# count  120.000000  120.000000    120.000000  120.000000  120.000000  ...
# mean     1.158333    2.008333      0.208333   72.000000   55.716667  ...
# std      0.788529    0.939299      0.407819   14.454798   14.795061  ...
# ...

# %%
df
# Out:
#      Student_ID     Sex Social Status  Age Governorate Living  \
# 0             1    Male        single    2     baghdad   city
# 1             2    Male        single    3     baghdad   city
# 2             3    Male        single    2     baghdad   city
# 3             4    Male       coupled    3     baghdad   city
# 4             5    Male        single    2     baghdad   city
# ..          ...     ...           ...  ...         ...    ...
# 115         116  Female        single    2     baghdad   city
# 116         117  Female       coupled    3     baghdad   city
# 117         118  Female        single    2     baghdad   city
# 118         119  Female        single    4       other   city
# 119         120  Female        single    2     baghdad   city
#
#     Mother education Father education Family member Education Father Alive  \
# 0          secondary        secondary                     yes          yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Student_ID                120 non-null    int64
#  1   Sex                       120 non-null    object
#  2   Social Status             120 non-null    object
#  3   Age                       120 non-null    int64
#  4   Governorate               120 non-null    object
#  5   Living                    120 non-null    object
#  6   Mother education          120 non-null    object
#  7   Father education          120 non-null    object
#  8   Family member Education   120 non-null    object
#  9   Father Alive              120 non-null    object
#  10  Mother Alive              120 non-null    object
#  11  Family Size               120 non-null    int64
#  12  Parent Apart              120 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Student_ID', 'Sex', 'Social Status', 'Age', 'Governorate', 'Living',
#        'Mother education', 'Father education', 'Family member Education',
#        'Father Alive', 'Mother Alive', 'Family Size', 'Parent Apart',
#        'The Guardian', 'Family Relationship', 'Father Job', 'Mother Job',
#        'Education Fee', 'Secondary Job', 'Home Ownership', 'Study Room',
#        'Family Economic Level', 'You  chronic disease',
#        'Family Chronic Disease', 'Specialization', 'Study willing',
#        'Reason of study', 'Attendance', 'Failure Year',
#        'Higher Education Willing', 'References Usage', 'Internet Usage',
#        'TV Usage', 'Sleep Hour', 'Study Hour', 'Arrival Time', 'Transport',
#        'Holiday Effect', 'Worry Effect', 'Parent Meeting', 'Islamea', 'arabic',
#        'english', 'math', 'physics', 'chemistry', 'economy/bio', 'Avg1',
#        'Islamea.1', 'arabic.1', 'english.1', 'math.1', 'physics.1',
#        'chemistry.1', 'economy/bio.1', 'Avg1.1'],
# ...

# %%
missingvalue = df.isnull().sum()
print(missingvalue)
# Out:
# Student_ID                   0
# Sex                          0
# Social Status                0
# Age                          0
# Governorate                  0
# Living                       0
# Mother education             0
# Father education             0
# Family member Education      0
# Father Alive                 0
# Mother Alive                 0
# Family Size                  0
# Parent Apart                 0
# The Guardian                99
# Family Relationship          0
# Father Job                   0
# Mother Job                   0
# Education Fee                0
# Secondary Job                0
# Home Ownership               0
# Study Room                   0
# Family Economic Level        0
# You  chronic disease         0
# Family Chronic Disease       0
# Specialization               0
# Study willing                0
# Reason of study              0
# Attendance                   0
# Failure Year                 0
# Higher Education Willing     0
# ...

# %%
df.describe()
# Out:
#        Student_ID         Age  Family Size  Internet Usage    TV Usage  \
# count  120.000000  120.000000   120.000000      120.000000  120.000000
# mean    60.500000    2.166667     0.500000        0.500000    0.141667
# std     34.785054    0.539737     0.648204        0.744729    0.435713
# min      1.000000    1.000000     0.000000        0.000000    0.000000
# 25%     30.750000    2.000000     0.000000        0.000000    0.000000
# 50%     60.500000    2.000000     0.000000        0.000000    0.000000
# 75%     90.250000    2.000000     1.000000        1.000000    0.000000
# max    120.000000    4.000000     2.000000        2.000000    2.000000
#
#        Sleep Hour  Study Hour  Arrival Time     Islamea      arabic  ...  \
# count  120.000000  120.000000    120.000000  120.000000  120.000000  ...
# mean     1.158333    2.008333      0.208333   72.000000   55.716667  ...
# std      0.788529    0.939299      0.407819   14.454798   14.795061  ...
# ...

# %% [markdown]
# ### Data cleaning means fixing bad data in your data set.
#
# Bad data could be:
#
# 1. Empty cells
# 2. Data in wrong format
# 3. Wrong data
# 4. Duplicates

# %%
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 115       NaN
# 116       NaN
# 117    mother
# 118    father
# 119       NaN
# Name: The Guardian, Length: 120, dtype: object

# %%
df["The Guardian"].fillna("Not Availabe", inplace = True) #to fill the na values with certail other values. ###IMPORTANT

# %%
import pandas as pd
new = df["Avg1.1"].mean()

# %%
df["The Guardian"]
# Out:
# 0      Not Availabe
# 1      Not Availabe
# 2      Not Availabe
# 3      Not Availabe
# 4      Not Availabe
#            ...
# 115    Not Availabe
# 116    Not Availabe
# 117          mother
# 118          father
# 119    Not Availabe
# Name: The Guardian, Length: 120, dtype: object

# %%
df.head()
# Out:
#    Student_ID   Sex Social Status  Age Governorate Living Mother education  \
# 0           1  Male        single    2     baghdad   city        secondary
# 1           2  Male        single    3     baghdad   city           medium
# 2           3  Male        single    2     baghdad   city       Illiterate
# 3           4  Male       coupled    3     baghdad   city               ba
# 4           5  Male        single    2     baghdad   city        secondary
#
#   Father education Family member Education Father Alive  ... economy/bio  \
# 0        secondary                     yes          yes  ...          70
# 1           higher                     yes          yes  ...          87
# 2        secondary                      no          yes  ...          58
# 3               ba                     yes          yes  ...          92
# 4        secondary                     yes          yes  ...          60
#
#    Avg1 Islamea.1 arabic.1 english.1 math.1 physics.1 chemistry.1  \
# ...

# %%
df[["Age"]].hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)
