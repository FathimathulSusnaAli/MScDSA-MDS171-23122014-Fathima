# %%
# Define an empty list to store prescriptions
prescriptions = []

# Function to add a prescription
def add_prescription(patient_name, medication, dosage):
    prescription = {
        "Patient Name": patient_name,
        "Medication": medication,
        "Dosage": dosage
    }
    prescriptions.append(prescription)

# Function to display all prescriptions
def display_prescriptions():
    if len(prescriptions) == 0:
        print("No prescriptions available.")
    else:
        for index, prescription in enumerate(prescriptions, start=1):
            print(f"Prescription {index}:")
            for key, value in prescription.items():
                print(f"{key}: {value}")
            print("\n")

# Function to search for prescriptions by patient name
def search_prescription(patient_name):
    found_prescriptions = []
    for prescription in prescriptions:
        if prescription["Patient Name"].lower() == patient_name.lower():
            found_prescriptions.append(prescription)
    if found_prescriptions:
        for prescription in found_prescriptions:
            print("Prescription found:")
            for key, value in prescription.items():
                print(f"{key}: {value}")
            print("\n")
    else:
        print("Prescription not found.")

# Function to remove a prescription
def remove_prescription(patient_name):
    global prescriptions
    updated_prescriptions = [p for p in prescriptions if p["Patient Name"].lower() != patient_name.lower()]
    if len(updated_prescriptions) < len(prescriptions):
        prescriptions = updated_prescriptions
        print("Prescription removed successfully.")
    else:
        print("Prescription not found.")

# Main program loop
while True:
    print("Prescription Handling System")
    print("1. Add Prescription")
    print("2. Display Prescriptions")
    print("3. Search Prescription")
    print("4. Remove Prescription")
    print("5. Exit")
    
    choice = input("Enter your choice (1/2/3/4/5): ")

    if choice == "1":
        patient_name = input("Enter patient name: ")
        medication = input("Enter medication: ")
        dosage = input("Enter dosage: ")
        add_prescription(patient_name, medication, dosage)
        print("Prescription added successfully.")
    elif choice == "2":
        display_prescriptions()
    elif choice == "3":
        patient_name = input("Enter patient name to search for: ")
        search_prescription(patient_name)
    elif choice == "4":
        patient_name = input("Enter patient name to remove prescription: ")
        remove_prescription(patient_name)
    elif choice == "5":
        print("Exiting program.")
        break
    else:
        print("Invalid choice. Please choose a valid option.")
# This script provides a basic command-line interface for adding, displaying, searching, and removing doctor prescriptions using lists, dictionaries, functions, and conditional statements. You can expand and customize it according to your specific requirements.
# Out:
# Prescription Handling System
# 1. Add Prescription
# 2. Display Prescriptions
# 3. Search Prescription
# 4. Remove Prescription
# 5. Exit
# Invalid choice. Please choose a valid option.
# Prescription Handling System
# 1. Add Prescription
# 2. Display Prescriptions
# 3. Search Prescription
# 4. Remove Prescription
# 5. Exit
# Prescription added successfully.
# Prescription Handling System
# 1. Add Prescription
# 2. Display Prescriptions
# 3. Search Prescription
# 4. Remove Prescription
# 5. Exit
# Invalid choice. Please choose a valid option.
# Prescription Handling System
# 1. Add Prescription
# 2. Display Prescriptions
# 3. Search Prescription
# 4. Remove Prescription
# 5. Exit
# Prescription 1:
# Patient Name: 1
# Medication: aa
# Dosage: aa
#
#
# Prescription Handling System
# 1. Add Prescription
# 2. Display Prescriptions
# 3. Search Prescription
# 4. Remove Prescription
# 5. Exit
# Prescription 1:
# Patient Name: 1
# Medication: aa
# Dosage: aa
#
#
# ...

# %% [markdown]
# ### Health Care System

# %%
def healthCareDetails():
    file = open("HealthCareSystem.csv","r+")
    Patient_Name=input("Enter the Name: ")
    Age = input("Enter Your Age: ")
    Doctors_Name = input("Enter the Doctor's Name: ")
    Type_of_Disease = input("Enter the Disease: ")
    Drug_Name= input("Enter the Prescribed Drug: ")
    Dosage = input("Enter the Quantity Prescribed: ")    #frequency required?
    header = ['Patients Name', 'Age', 'Doctors Name','Type of Disease','Drug Name',"Dosage"] #file.writerow(header)
    file.write( Patient_Name+",\t"+Age+",\t"+Doctors_Name+",\t"+Type_of_Disease+",\t"+Drug_Name+",\t"+Dosage)
    file.close()

def Search():
    file = open("HealthCareSystem.csv","r+")
    name = input("Please Enter the Patient Name to know more about your prescription ").strip()
    prescribed_list=[]
    for line in file.readlines():
        line = line.strip().split(',')
        print(line)
        if line[0] == name:
            name1 = line[0] 
            age = line[1]
            doctors_name = line[2]
            diseasetype = line[3]
            drug_name = line[4]
            dosage = line[5]
            print("The Patients Details")
            print("Name: ",name1.strip())
            print("Age: ",age.strip())
            print("The Consulted Doctors Name: ",doctors_name.strip())
            print("The Disease type is: ",diseasetype.strip())
            print("The prescribed Drug Name: ",drug_name.strip())
            print("The prescribed Dosage by the Doctor: ",dosage.strip())
        else:
            print("Not Available")
# Search()


def Display():
    file = open("HealthCareSystem.csv","r+")
    for item in file:
        print(item)


def Editing():
    file = open("HealthCareSystem.csv","r")
    input_user = input("Please Enter the Name")
    for line in file.readlines():
        # if line == input_user:

            print(line.strip())

# Editing()   

        

while True:
    print("Prescription Handling System")
    print("1. Add Prescription")
    print("2. Display Prescriptions")
    print("3. Search Prescription")
    print("4. Remove Prescription")
    print("5. Exit")
    choice = input("Please Enter the Choice: ")
    if choice =="1":
        healthCareDetails()  #done
    elif choice == "2":         #to think 
        Display()
    elif choice =="3":       #done
        Search()
    # elif choice == "4":       #todo
    #     Delete()
    elif choice =="5":
        exit()
    else:
        print("Enter the Valid Input!")
# Out:
# Prescription Handling System
# 1. Add Prescription
# 2. Display Prescriptions
# 3. Search Prescription
# 4. Remove Prescription
# 5. Exit
# Prescription Handling System
# 1. Add Prescription
# 2. Display Prescriptions
# 3. Search Prescription
# 4. Remove Prescription
# 5. Exit
# Prescription Handling System
# 1. Add Prescription
# 2. Display Prescriptions
# 3. Search Prescription
# 4. Remove Prescription
# 5. Exit
# Prescription Handling System
# 1. Add Prescription
# 2. Display Prescriptions
# 3. Search Prescription
# 4. Remove Prescription
# 5. Exit
# Enter the Valid Input!
# Prescription Handling System
# 1. Add Prescription
# 2. Display Prescriptions
# 3. Search Prescription
# 4. Remove Prescription
# 5. Exit
# ...

# %% [markdown]
# ## Analysis Part

# %%
# healthCareDetails()
file = open("HealthCareSystem.csv","r+")
for line in file.readlines():
    fields = line.strip().split(',')
    Age = int(fields[1].strip())
    # Age = int(line[1])
    count1,count2,count3=0,0,0

    # Define age groups
    if Age < 18:
        age_group = "Pediatric"
        count1 +=1
        print("The Children or the Youngsters also suffers with a count from the dataset of ",count1)
    elif 18 <= Age < 65:
        count2+=1
        print("The Adults who suffers with a count from the dataset of ",count2)
        age_group = "Adult"
    else:
        count3+=1
        print("The Elderly who suffers with a count from the dataset of ",count3)
        age_group = "Elderly"
# Out:
# The Adults who suffers with a count from the dataset of  1

# %%
# Create an empty list to store disease counts as tuples
disease_counts_list = []

file = open("HealthCareSystem.csv","r+")

# Populate the list with tuples of disease counts
for disease, count in disease_counts.items():
    disease_counts_list.append((disease, count))

# Sort the list by count in descending order using a custom sorting function
def sort_by_count(item):
    return item[1]

disease_counts_list.sort(key=sort_by_count, reverse=True)

# Print disease counts
for disease, count in disease_counts_list:
    print(f"{disease}: {count} cases")
# Out:
# Heart: 1 cases

# %%
def healthCareDetails():
    file = open("HealthCareSystem.csv","a+")
    Patient_Name=input("Enter the Name: ")
    Age = input("Enter Your Age: ")
    Doctors_Name = input("Enter the Doctor's Name: ")
    Type_of_Disease = input("Enter the Disease: ")
    Drug_Name= input("Enter the Prescribed Drug: ")
    Dosage = input("Enter the Quantity Prescribed: ")    #frequency required?
    header = ['Patients Name', 'Age', 'Doctors Name','Type of Disease','Drug Name',"Dosage"] #file.writerow(header)
    file.write( Patient_Name+","+Age+","+Doctors_Name+","+Type_of_Disease+","+Drug_Name+","+Dosage)
    file.close()
def Display():
    file = open("HealthCareSystem.csv","r+")
    name = input("Please Enter the Patient Name to know more about your prescription ".lower())
    flag = True
    for line in file:
        line = line.strip().split(",") 
        print(line)
        if line[0].lower() == name:
                print(line)
                flag = True
        else:
            print("The Entered Prescription is not currently available, Please Contact the Admin!")
            flag = False

healthCareDetails()
Display()

# %%
def healthCareDetails():
    file = open("HealthCareSystem.csv","w+")
    Patient_Name=input("Enter the Name: ")
    Age = input("Enter Your Age: ")
    Doctors_Name = input("Enter the Doctor's Name: ")
    Type_of_Disease = input("Enter the Disease: ")
    Drug_Name= input("Enter the Prescribed Drug: ")
    Dosage = input("Enter the Quantity Prescribed: ")    #frequency required?
    header = ['Patients Name', 'Age', 'Doctors Name','Type of Disease','Drug Name',"Dosage"] #file.writerow(header)
    file.write( Patient_Name+",\t"+Age+",\t"+Doctors_Name+",\t"+Type_of_Disease+",\t"+Drug_Name+",\t"+Dosage)
    file.close()




def Search():
    file = open("HealthCareSystem.csv","r+")
    name = input("Please Enter the Patient Name to know more about your prescription ".lower())
    flag = True
    for line in file:
        line = line.strip().split(",") 
        print(line)
        if line[0].lower() == name:
                print(line)
                flag = True
        else:
            print("The Entered Prescription is not currently available, Please Contact the Admin!")
            flag = False

healthCareDetails()
Display()
Search()
# Out:
# Fathima,	22,	Sini,	Heart,	Amoxilin,	21ml
# ['Fathima', '\t22', '\tSini', '\tHeart', '\tAmoxilin', '\t21ml']
# The Entered Prescription is not currently available, Please Contact the Admin!

# %%
healthCareDetails()

# %%
import csv

def healthCareDetails():
    # Open the CSV file in write mode with 'newline' set to empty string
    with open("HealthCareSystem.csv", "w", newline='') as file:
        # Create a CSV writer object
        writer = csv.writer(file)

        # Write the header row
        header = ['Patient_Name', 'Age', 'Doctors_Name', 'Type_of_Disease', 'Drug_Name', 'Dosage']
        writer.writerow(header)

        # Collect user input
        Patient_Name = input("Enter the Name: ")
        Age = input("Enter Your Age: ")
        Doctors_Name = input("Enter the Doctor's Name: ")
        Type_of_Disease = input("Enter the Disease: ")
        Drug_Name = input("Enter the Prescribed Drug: ")
        Dosage = input("Enter the Quantity Prescribed: ")

        # Write the user data to the CSV file
        data = [Patient_Name, Age, Doctors_Name, Type_of_Disease, Drug_Name, Dosage]
        writer.writerow(data)

# Call the function to collect and write data
healthCareDetails()

# %%
class expensetracker():
    def __init__(self):

        self.transactions = {
            "Expenses" : [],
            "Income" :[]
        }

    def storetransaction(self,type,category,cost,desc,date):
        # type : expense / income
        # type: type/category
        # category: descriptions on the transactions
        # date [DD/MM/YYYY]

        transaction = {
            "Category":category,
            "Cost":cost,
            "Description":desc,
            "Date":date
        }
        if type == "Expenses":
            self.transactions["Expenses"].append(transaction)
        else: 
            self.transactions["Income"].append(transaction)
        return True
    def view_transactions(self):
        # print("INCOME")
        for expenses in self.transactions['Expenses']:
            print(expenses)
        # self.transactions
    def total_incomeexpense(self):
        print("Total Income")
        total_income = 0
        for income in self.transactions['Income']:
            total_income+=income["Cost"]
        print(total_income)
        
        print("Total Expense")
        total_expense = 0
        for expenses in self.transactions['Expenses']:
            total_expense+=expenses["Cost"]
        print(total_expense)


    
expenseTracker = expensetracker()
expenseTracker.storetransaction("Expense","Electricity Bill",4500,"MDHC","20/09/2023")
expenseTracker.storetransaction("Income","Salary",60000,"Amazon","21/09/2023")
expenseTracker.storetransaction("Income","Pocket Money",10000,"Parents","29/10/2023")
expenseTracker.storetransaction("Income","Internship Salary",10000,"Google","30/10/2023")
expenseTracker.storetransaction("Expense","Groceries",5000,"SUpermarket","30/10/2023")
expenseTracker.view_transactions()
# expenseTracker.total_incomeexpense()
# while True:
#     print("1.Enter the options to save the Expense/Income:")
#     print("2.Enter the Category you would like to choose:")
#     print("3.Please select this option to ")
